# %%
# !python -m src.train_ppo_optimized
# Out:
# UndefVarError: `python` not defined in `Main`
# Suggestion: check for spelling errors or missing imports.
#
# Stacktrace:
#  [1] top-level scope
#    @ In[1]:1
